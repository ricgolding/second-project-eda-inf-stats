# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random
# from textwrap import wrap

import functions as f

# %matplotlib inline

# %run cleaning_demo.ipynb
# %run cleaning_web_data.ipynb
# %run cleaning_experiment_clients.ipynb

# df_demo = import_df_demo() # type: ignore
# df_web_data = import_df_web_data() # type: ignore
# df_experiment_clients = import_df_experiment_clients() # type: ignore

df_demo = pd.read_csv("../data/clean/df_demo_clean.csv")
df_web_data = pd.read_csv("../data/clean/df_web_data_clean.csv")
df_experiment_clients = pd.read_csv("../data/clean/df_experiment_clients_clean.csv")

# %%
df_demo, df_web_data, df_experiment_clients

df_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70078 entries, 0 to 70077
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   client_id         70078 non-null  int64
#  1   clnt_tenure_yr    70078 non-null  int64
#  2   clnt_tenure_mnth  70078 non-null  int64
#  3   clnt_age          70078 non-null  int64
#  4   gendr             70078 non-null  object
#  5   num_accts         70078 non-null  int64
#  6   bal               70078 non-null  float64
#  7   calls_6_mnth      70078 non-null  int64
#  8   logons_6_mnth     70078 non-null  int64
#  9   tenure            70078 non-null  object
#  10  age_group         70078 non-null  object
#  11  bal_category_3    70078 non-null  object
#  12  bal_category_2    70078 non-null  object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 7.0+ MB

# %%
# Merge first two dataframes
df_merge_1 = pd.merge(df_web_data, df_demo, on="client_id", how="left")

# Merge resting dataframe
df_merge_2 = pd.merge(df_merge_1, df_experiment_clients, on="client_id", how="left")

df_merge_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#         process_step            date_time  clnt_tenure_yr  clnt_tenure_mnth  \
# 0                  3  2017-04-17 15:27:07             5.0              64.0
# 1                  2  2017-04-17 15:26:51             5.0              64.0
# 2                  3  2017-04-17 15:19:22             5.0              64.0
# 3                  2  2017-04-17 15:19:13             5.0              64.0
# 4                  3  2017-04-17 15:18:04             5.0              64.0
# ...              ...                  ...             ...               ...
# 755400             0  2017-05-24 18:46:10             NaN               NaN
# 755401             0  2017-05-24 18:45:29             NaN               NaN
# 755402             1  2017-05-24 18:44:51             NaN               NaN
# 755403             0  2017-05-24 18:44:34             NaN               NaN
# 755404             0  2017-06-03 12:17:09             NaN               NaN
#
#         clnt_age gendr  num_accts        bal  calls_6_mnth  logons_6_mnth  \
# 0           79.0     U        2.0  189023.86           1.0            4.0
# 1           79.0     U        2.0  189023.86           1.0            4.0
# 2           79.0     U        2.0  189023.86           1.0            4.0
# 3           79.0     U        2.0  189023.86           1.0            4.0
# 4           79.0     U        2.0  189023.86           1.0            4.0
# ...          ...   ...        ...        ...           ...            ...
# 755400       NaN   NaN        NaN        NaN           NaN            NaN
# 755401       NaN   NaN        NaN        NaN           NaN            NaN
# 755402       NaN   NaN        NaN        NaN           NaN            NaN
# 755403       NaN   NaN        NaN        NaN           NaN            NaN
# 755404       NaN   NaN        NaN        NaN           NaN            NaN
#
#             tenure age_group bal_category_3 bal_category_2 Variation
# 0       New Client   Elderly         Medium           High      Test
# 1       New Client   Elderly         Medium           High      Test
# 2       New Client   Elderly         Medium           High      Test
# 3       New Client   Elderly         Medium           High      Test
# 4       New Client   Elderly         Medium           High      Test
# ...            ...       ...            ...            ...       ...
# 755400         NaN       NaN            NaN            NaN       NaN
# 755401         NaN       NaN            NaN            NaN       NaN
# 755402         NaN       NaN            NaN            NaN       NaN
# 755403         NaN       NaN            NaN            NaN       NaN
# 755404         NaN       NaN            NaN            NaN       NaN
#
# [755405 rows x 18 columns]

# %%
df_merge_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755405 entries, 0 to 755404
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   client_id         755405 non-null  int64
#  1   visitor_id        755405 non-null  object
#  2   visit_id          755405 non-null  object
#  3   process_step      755405 non-null  int64
#  4   date_time         755405 non-null  object
#  5   clnt_tenure_yr    446674 non-null  float64
#  6   clnt_tenure_mnth  446674 non-null  float64
#  7   clnt_age          446674 non-null  float64
#  8   gendr             446674 non-null  object
#  9   num_accts         446674 non-null  float64
#  10  bal               446674 non-null  float64
#  11  calls_6_mnth      446674 non-null  float64
#  12  logons_6_mnth     446674 non-null  float64
#  13  tenure            446674 non-null  object
#  14  age_group         446674 non-null  object
#  15  bal_category_3    446674 non-null  object
#  16  bal_category_2    446674 non-null  object
#  17  Variation         321309 non-null  object
# dtypes: float64(7), int64(2), object(9)
# memory usage: 103.7+ MB

# %%
# Check random client_ids

list_of_ids = df_merge_2["client_id"].to_list()
df_merge_2[df_merge_2["client_id"] == random.choice(list_of_ids)]
# Out:
#        client_id             visitor_id                      visit_id  \
# 66091    2328764  987799546_76550562192  987155805_87448099277_933284
# 66092    2328764  987799546_76550562192  987155805_87448099277_933284
# 66120    2328764  140871677_99117796206   914569228_82130515670_14818
# 66121    2328764  140871677_99117796206   914569228_82130515670_14818
# 66122    2328764  140871677_99117796206   914569228_82130515670_14818
# 66123    2328764  140871677_99117796206   914569228_82130515670_14818
# 66124    2328764  140871677_99117796206   914569228_82130515670_14818
# 66164    2328764  987799546_76550562192  987155805_87448099277_933284
# 66165    2328764  987799546_76550562192  987155805_87448099277_933284
# 66166    2328764  987799546_76550562192  987155805_87448099277_933284
# 66167    2328764  987799546_76550562192  987155805_87448099277_933284
# 66168    2328764  987799546_76550562192  987155805_87448099277_933284
# 66169    2328764  987799546_76550562192  987155805_87448099277_933284
# 66170    2328764  987799546_76550562192  987155805_87448099277_933284
# 66171    2328764  987799546_76550562192  987155805_87448099277_933284
# 66172    2328764  987799546_76550562192  987155805_87448099277_933284
# 66173    2328764  987799546_76550562192  987155805_87448099277_933284
#
#        process_step            date_time  clnt_tenure_yr  clnt_tenure_mnth  \
# 66091             0  2017-04-02 14:36:16            18.0             216.0
# 66092             0  2017-04-02 14:34:40            18.0             216.0
# 66120             2  2017-03-26 13:00:38            18.0             216.0
# 66121             1  2017-03-26 13:00:09            18.0             216.0
# 66122             0  2017-03-26 12:59:36            18.0             216.0
# 66123             0  2017-03-26 12:58:01            18.0             216.0
# 66124             0  2017-03-26 12:57:36            18.0             216.0
# 66164             3  2017-04-02 14:31:42            18.0             216.0
# 66165             2  2017-04-02 14:31:24            18.0             216.0
# 66166             3  2017-04-02 14:31:05            18.0             216.0
# 66167             2  2017-04-02 14:30:55            18.0             216.0
# 66168             3  2017-04-02 14:30:22            18.0             216.0
# 66169             2  2017-04-02 14:30:12            18.0             216.0
# 66170             3  2017-04-02 14:26:57            18.0             216.0
# 66171             2  2017-04-02 14:23:33            18.0             216.0
# 66172             1  2017-04-02 14:23:27            18.0             216.0
# 66173             0  2017-04-02 14:23:17            18.0             216.0
#
#        clnt_age gendr  num_accts        bal  calls_6_mnth  logons_6_mnth  \
# 66091      47.0     M        3.0  416911.21           6.0            9.0
# 66092      47.0     M        3.0  416911.21           6.0            9.0
# 66120      47.0     M        3.0  416911.21           6.0            9.0
# 66121      47.0     M        3.0  416911.21           6.0            9.0
# 66122      47.0     M        3.0  416911.21           6.0            9.0
# 66123      47.0     M        3.0  416911.21           6.0            9.0
# 66124      47.0     M        3.0  416911.21           6.0            9.0
# 66164      47.0     M        3.0  416911.21           6.0            9.0
# 66165      47.0     M        3.0  416911.21           6.0            9.0
# 66166      47.0     M        3.0  416911.21           6.0            9.0
# 66167      47.0     M        3.0  416911.21           6.0            9.0
# 66168      47.0     M        3.0  416911.21           6.0            9.0
# 66169      47.0     M        3.0  416911.21           6.0            9.0
# 66170      47.0     M        3.0  416911.21           6.0            9.0
# 66171      47.0     M        3.0  416911.21           6.0            9.0
# 66172      47.0     M        3.0  416911.21           6.0            9.0
# 66173      47.0     M        3.0  416911.21           6.0            9.0
#
#                      tenure age_group bal_category_3 bal_category_2 Variation
# 66091  Long Standing Client    Adults         Medium           High   Control
# 66092  Long Standing Client    Adults         Medium           High   Control
# 66120  Long Standing Client    Adults         Medium           High   Control
# 66121  Long Standing Client    Adults         Medium           High   Control
# 66122  Long Standing Client    Adults         Medium           High   Control
# 66123  Long Standing Client    Adults         Medium           High   Control
# 66124  Long Standing Client    Adults         Medium           High   Control
# 66164  Long Standing Client    Adults         Medium           High   Control
# 66165  Long Standing Client    Adults         Medium           High   Control
# 66166  Long Standing Client    Adults         Medium           High   Control
# 66167  Long Standing Client    Adults         Medium           High   Control
# 66168  Long Standing Client    Adults         Medium           High   Control
# 66169  Long Standing Client    Adults         Medium           High   Control
# 66170  Long Standing Client    Adults         Medium           High   Control
# 66171  Long Standing Client    Adults         Medium           High   Control
# 66172  Long Standing Client    Adults         Medium           High   Control
# 66173  Long Standing Client    Adults         Medium           High   Control

# %%
# Check for NaN values count
df_merge_2.isna().sum()
# Out:
# client_id                0
# visitor_id               0
# visit_id                 0
# process_step             0
# date_time                0
# clnt_tenure_yr      308731
# clnt_tenure_mnth    308731
# clnt_age            308731
# gendr               308731
# num_accts           308731
# bal                 308731
# calls_6_mnth        308731
# logons_6_mnth       308731
# tenure              308731
# age_group           308731
# bal_category_3      308731
# bal_category_2      308731
# Variation           434096
# dtype: int64

# %%
# Drop NaN values
df_merge_2.dropna(how="any", inplace=True)
df_merge_2.reset_index(drop=True, inplace=True)

df_merge_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 319489    1574008  117364417_77840596075  528720790_71583064618_169151
# 319490    2908510  814969699_90652851448   562606085_36368381773_92090
# 319491    2908510  814969699_90652851448   562606085_36368381773_92090
# 319492    2908510  814969699_90652851448   562606085_36368381773_92090
# 319493    2908510  814969699_90652851448   562606085_36368381773_92090
#
#         process_step            date_time  clnt_tenure_yr  clnt_tenure_mnth  \
# 0                  3  2017-04-17 15:27:07             5.0              64.0
# 1                  2  2017-04-17 15:26:51             5.0              64.0
# 2                  3  2017-04-17 15:19:22             5.0              64.0
# 3                  2  2017-04-17 15:19:13             5.0              64.0
# 4                  3  2017-04-17 15:18:04             5.0              64.0
# ...              ...                  ...             ...               ...
# 319489             0  2017-05-06 23:43:27            10.0             121.0
# 319490             0  2017-05-10 22:57:17            21.0             252.0
# 319491             2  2017-05-10 22:56:31            21.0             252.0
# 319492             1  2017-05-10 22:56:23            21.0             252.0
# 319493             0  2017-05-10 22:56:20            21.0             252.0
#
#         clnt_age gendr  num_accts        bal  calls_6_mnth  logons_6_mnth  \
# 0           79.0     U        2.0  189023.86           1.0            4.0
# 1           79.0     U        2.0  189023.86           1.0            4.0
# 2           79.0     U        2.0  189023.86           1.0            4.0
# 3           79.0     U        2.0  189023.86           1.0            4.0
# 4           79.0     U        2.0  189023.86           1.0            4.0
# ...          ...   ...        ...        ...           ...            ...
# 319489      55.0     U        2.0  153238.83           3.0            6.0
# 319490      34.0     M        3.0  141808.05           6.0            9.0
# 319491      34.0     M        3.0  141808.05           6.0            9.0
# 319492      34.0     M        3.0  141808.05           6.0            9.0
# 319493      34.0     M        3.0  141808.05           6.0            9.0
#
#                       tenure age_group bal_category_3 bal_category_2 Variation
# 0                 New Client   Elderly         Medium           High      Test
# 1                 New Client   Elderly         Medium           High      Test
# 2                 New Client   Elderly         Medium           High      Test
# 3                 New Client   Elderly         Medium           High      Test
# 4                 New Client   Elderly         Medium           High      Test
# ...                      ...       ...            ...            ...       ...
# 319489  Long Standing Client    Senior         Medium           High      Test
# 319490  Long Standing Client    Adults         Medium           High   Control
# 319491  Long Standing Client    Adults         Medium           High   Control
# 319492  Long Standing Client    Adults         Medium           High   Control
# 319493  Long Standing Client    Adults         Medium           High   Control
#
# [319494 rows x 18 columns]

# %%
# Cast floats as integers
df_merge_2 = df_merge_2.astype({
    "clnt_tenure_yr": "int64", 
    "clnt_tenure_mnth": "int64",
    "clnt_age": "int64",
    "num_accts": "int64",
    "calls_6_mnth": "int64",
    "logons_6_mnth": "int64"
    })

df_merge_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 319489    1574008  117364417_77840596075  528720790_71583064618_169151
# 319490    2908510  814969699_90652851448   562606085_36368381773_92090
# 319491    2908510  814969699_90652851448   562606085_36368381773_92090
# 319492    2908510  814969699_90652851448   562606085_36368381773_92090
# 319493    2908510  814969699_90652851448   562606085_36368381773_92090
#
#         process_step            date_time  clnt_tenure_yr  clnt_tenure_mnth  \
# 0                  3  2017-04-17 15:27:07               5                64
# 1                  2  2017-04-17 15:26:51               5                64
# 2                  3  2017-04-17 15:19:22               5                64
# 3                  2  2017-04-17 15:19:13               5                64
# 4                  3  2017-04-17 15:18:04               5                64
# ...              ...                  ...             ...               ...
# 319489             0  2017-05-06 23:43:27              10               121
# 319490             0  2017-05-10 22:57:17              21               252
# 319491             2  2017-05-10 22:56:31              21               252
# 319492             1  2017-05-10 22:56:23              21               252
# 319493             0  2017-05-10 22:56:20              21               252
#
#         clnt_age gendr  num_accts        bal  calls_6_mnth  logons_6_mnth  \
# 0             79     U          2  189023.86             1              4
# 1             79     U          2  189023.86             1              4
# 2             79     U          2  189023.86             1              4
# 3             79     U          2  189023.86             1              4
# 4             79     U          2  189023.86             1              4
# ...          ...   ...        ...        ...           ...            ...
# 319489        55     U          2  153238.83             3              6
# 319490        34     M          3  141808.05             6              9
# 319491        34     M          3  141808.05             6              9
# 319492        34     M          3  141808.05             6              9
# 319493        34     M          3  141808.05             6              9
#
#                       tenure age_group bal_category_3 bal_category_2 Variation
# 0                 New Client   Elderly         Medium           High      Test
# 1                 New Client   Elderly         Medium           High      Test
# 2                 New Client   Elderly         Medium           High      Test
# 3                 New Client   Elderly         Medium           High      Test
# 4                 New Client   Elderly         Medium           High      Test
# ...                      ...       ...            ...            ...       ...
# 319489  Long Standing Client    Senior         Medium           High      Test
# 319490  Long Standing Client    Adults         Medium           High   Control
# 319491  Long Standing Client    Adults         Medium           High   Control
# 319492  Long Standing Client    Adults         Medium           High   Control
# 319493  Long Standing Client    Adults         Medium           High   Control
#
# [319494 rows x 18 columns]

# %%
# Cast date_time as datetime
df_merge_2['date_time'] = pd.to_datetime(df_merge_2['date_time'])
df_merge_2 = df_merge_2.sort_values(by=["client_id","date_time"], ascending=[True,True])
df_merge_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 70439         555  402506806_56087378777  637149525_38041617439_716659
# 70438         555  402506806_56087378777  637149525_38041617439_716659
# 70437         555  402506806_56087378777  637149525_38041617439_716659
# 70436         555  402506806_56087378777  637149525_38041617439_716659
# 70435         555  402506806_56087378777  637149525_38041617439_716659
# ...           ...                    ...                           ...
# 274608    9999729  834634258_21862004160  870243567_56915814033_814203
# 274607    9999729  834634258_21862004160  870243567_56915814033_814203
# 274606    9999729  834634258_21862004160  870243567_56915814033_814203
# 243640    9999832  145538019_54444341400  472154369_16714624241_585315
# 243639    9999832  145538019_54444341400  472154369_16714624241_585315
#
#         process_step           date_time  clnt_tenure_yr  clnt_tenure_mnth  \
# 70439              0 2017-04-15 12:57:56               3                46
# 70438              1 2017-04-15 12:58:03               3                46
# 70437              2 2017-04-15 12:58:35               3                46
# 70436              3 2017-04-15 13:00:14               3                46
# 70435              4 2017-04-15 13:00:34               3                46
# ...              ...                 ...             ...               ...
# 274608             2 2017-05-08 16:08:40              10               124
# 274607             3 2017-05-08 16:09:19              10               124
# 274606             4 2017-05-08 16:09:40              10               124
# 243640             0 2017-05-16 16:46:03              23               281
# 243639             1 2017-05-16 16:46:11              23               281
#
#         clnt_age gendr  num_accts        bal  calls_6_mnth  logons_6_mnth  \
# 70439         30     U          2   25454.66             2              6
# 70438         30     U          2   25454.66             2              6
# 70437         30     U          2   25454.66             2              6
# 70436         30     U          2   25454.66             2              6
# 70435         30     U          2   25454.66             2              6
# ...          ...   ...        ...        ...           ...            ...
# 274608        31     F          3  107059.74             6              9
# 274607        31     F          3  107059.74             6              9
# 274606        31     F          3  107059.74             6              9
# 243640        49     F          2  431887.61             1              4
# 243639        49     F          2  431887.61             1              4
#
#                       tenure    age_group bal_category_3 bal_category_2  \
# 70439             New Client  Young Adult            Low            Low
# 70438             New Client  Young Adult            Low            Low
# 70437             New Client  Young Adult            Low            Low
# 70436             New Client  Young Adult            Low            Low
# 70435             New Client  Young Adult            Low            Low
# ...                      ...          ...            ...            ...
# 274608  Long Standing Client       Adults         Medium           High
# 274607  Long Standing Client       Adults         Medium           High
# 274606  Long Standing Client       Adults         Medium           High
# 243640  Long Standing Client       Adults         Medium           High
# 243639  Long Standing Client       Adults         Medium           High
#
#        Variation
# 70439       Test
# 70438       Test
# 70437       Test
# 70436       Test
# 70435       Test
# ...          ...
# 274608      Test
# 274607      Test
# 274606      Test
# 243640      Test
# 243639      Test
#
# [319494 rows x 18 columns]

# %%
# Round Balance (bal) to 2 decimals
df_merge_2['bal'] = df_merge_2['bal'].apply(lambda x: round(x, 2))
df_merge_2
# Out:
#         client_id             visitor_id                      visit_id  \
# 70439         555  402506806_56087378777  637149525_38041617439_716659
# 70438         555  402506806_56087378777  637149525_38041617439_716659
# 70437         555  402506806_56087378777  637149525_38041617439_716659
# 70436         555  402506806_56087378777  637149525_38041617439_716659
# 70435         555  402506806_56087378777  637149525_38041617439_716659
# ...           ...                    ...                           ...
# 274608    9999729  834634258_21862004160  870243567_56915814033_814203
# 274607    9999729  834634258_21862004160  870243567_56915814033_814203
# 274606    9999729  834634258_21862004160  870243567_56915814033_814203
# 243640    9999832  145538019_54444341400  472154369_16714624241_585315
# 243639    9999832  145538019_54444341400  472154369_16714624241_585315
#
#         process_step           date_time  clnt_tenure_yr  clnt_tenure_mnth  \
# 70439              0 2017-04-15 12:57:56               3                46
# 70438              1 2017-04-15 12:58:03               3                46
# 70437              2 2017-04-15 12:58:35               3                46
# 70436              3 2017-04-15 13:00:14               3                46
# 70435              4 2017-04-15 13:00:34               3                46
# ...              ...                 ...             ...               ...
# 274608             2 2017-05-08 16:08:40              10               124
# 274607             3 2017-05-08 16:09:19              10               124
# 274606             4 2017-05-08 16:09:40              10               124
# 243640             0 2017-05-16 16:46:03              23               281
# 243639             1 2017-05-16 16:46:11              23               281
#
#         clnt_age gendr  num_accts        bal  calls_6_mnth  logons_6_mnth  \
# 70439         30     U          2   25454.66             2              6
# 70438         30     U          2   25454.66             2              6
# 70437         30     U          2   25454.66             2              6
# 70436         30     U          2   25454.66             2              6
# 70435         30     U          2   25454.66             2              6
# ...          ...   ...        ...        ...           ...            ...
# 274608        31     F          3  107059.74             6              9
# 274607        31     F          3  107059.74             6              9
# 274606        31     F          3  107059.74             6              9
# 243640        49     F          2  431887.61             1              4
# 243639        49     F          2  431887.61             1              4
#
#                       tenure    age_group bal_category_3 bal_category_2  \
# 70439             New Client  Young Adult            Low            Low
# 70438             New Client  Young Adult            Low            Low
# 70437             New Client  Young Adult            Low            Low
# 70436             New Client  Young Adult            Low            Low
# 70435             New Client  Young Adult            Low            Low
# ...                      ...          ...            ...            ...
# 274608  Long Standing Client       Adults         Medium           High
# 274607  Long Standing Client       Adults         Medium           High
# 274606  Long Standing Client       Adults         Medium           High
# 243640  Long Standing Client       Adults         Medium           High
# 243639  Long Standing Client       Adults         Medium           High
#
#        Variation
# 70439       Test
# 70438       Test
# 70437       Test
# 70436       Test
# 70435       Test
# ...          ...
# 274608      Test
# 274607      Test
# 274606      Test
# 243640      Test
# 243639      Test
#
# [319494 rows x 18 columns]

# %%
#Added session started and completed columns.
df_merge_2['session_completed'] = df_merge_2.groupby('visit_id')['process_step'].transform(lambda x: 1 if (4 in x.values) else 0)
# Check if a visit_id has any process_step = 0
df_merge_2['session_started'] = df_merge_2.groupby('visit_id')['process_step'].transform(lambda x: 1 if (0 in x.values) else 0)

df_step_4 = df_merge_2[df_merge_2['process_step'] == 4]
df_step_4_sorted = df_step_4.sort_values(by='date_time', ascending=True)
df_step_4_cleaned = df_step_4_sorted.drop_duplicates(subset=['client_id', 'visit_id', 'visitor_id'], keep='first')
df_non_step_4 = df_merge_2[df_merge_2['process_step'] != 4]
df_merge_2 = pd.concat([df_non_step_4, df_step_4_cleaned])
df_merge_2 = df_merge_2.reset_index(drop=True)

# %%
#Created different DF for error rate.
merged_grouped =df_merge_2.groupby(['client_id', 'visit_id', 'visitor_id','Variation'])['process_step'].apply(list).reset_index()

# create new column as error rate and apply the method on all clients in dataframe
merged_grouped['error_rate'] = merged_grouped.apply(
    lambda row: f.backward_steps_for_client(row['process_step'], row['client_id'],row['Variation'])[row['client_id']],
    axis=1  # Process each row individually
)

# %%
# Rename dataframe to export
df_join_clean = df_merge_2

# %%
# Evaluates funnel conversion. Step progresion status.

df_join_clean['steps_status'] = None
previous_visit_id = None
previous_value = None

for i in range(len(df_join_clean)):
    current_visit_id = df_join_clean.iloc[i]["visit_id"]
    current_value = df_join_clean.iloc[i]["process_step"]

    if current_value == 0:
        df_join_clean.iloc[i, df_join_clean.columns.get_loc('steps_status')] = 0
    else:
        if previous_value > current_value:
            df_join_clean.iloc[i, df_join_clean.columns.get_loc('steps_status')] = -1
        if previous_value == current_value:
            df_join_clean.iloc[i, df_join_clean.columns.get_loc('steps_status')] = 0
        if previous_value < current_value:
            df_join_clean.iloc[i, df_join_clean.columns.get_loc('steps_status')] = 1
        # if current_value == 4:
        #     df_join_clean.iloc[i, df_join_clean.columns.get_loc('steps_status')] = "confirm"
    
    previous_value = current_value

display(df_join_clean)
# Out:
#         client_id             visitor_id                      visit_id  \
# 0             555  402506806_56087378777  637149525_38041617439_716659
# 1             555  402506806_56087378777  637149525_38041617439_716659
# 2             555  402506806_56087378777  637149525_38041617439_716659
# 3             555  402506806_56087378777  637149525_38041617439_716659
# 4             647   66758770_53988066587   40369564_40101682850_311847
# ...           ...                    ...                           ...
# 314163    8087297  705480062_61677487543  382863409_32223115689_382818
# 314164    9358802  942961634_72894201792   994534828_9307546636_924563
# 314165     351901  441550691_95235779278   20921390_15666229944_683250
# 314166    1545935  976873968_42239039722   10056419_61656665964_803695
# 314167    1558312  397562195_28573798537  175513303_32086468382_224926
#
#         process_step           date_time  clnt_tenure_yr  clnt_tenure_mnth  \
# 0                  0 2017-04-15 12:57:56               3                46
# 1                  1 2017-04-15 12:58:03               3                46
# 2                  2 2017-04-15 12:58:35               3                46
# 3                  3 2017-04-15 13:00:14               3                46
# 4                  0 2017-04-12 15:41:28              12               151
# ...              ...                 ...             ...               ...
# 314163             4 2017-06-20 22:31:10               6                77
# 314164             4 2017-06-20 22:32:06              14               175
# 314165             4 2017-06-20 22:44:04              11               137
# 314166             4 2017-06-20 23:21:23               4                59
# 314167             4 2017-06-20 23:26:00              23               276
#
#         clnt_age gendr  num_accts  ...  calls_6_mnth  logons_6_mnth  \
# 0             30     U          2  ...             2              6
# 1             30     U          2  ...             2              6
# 2             30     U          2  ...             2              6
# 3             30     U          2  ...             2              6
# 4             58     M          2  ...             0              4
# ...          ...   ...        ...  ...           ...            ...
# 314163        45     U          2  ...             4              7
# 314164        33     F          2  ...             6              9
# 314165        36     F          4  ...             6              9
# 314166        24     F          3  ...             5              8
# 314167        64     F          2  ...             2              5
#
#                       tenure    age_group bal_category_3 bal_category_2  \
# 0                 New Client  Young Adult            Low            Low
# 1                 New Client  Young Adult            Low            Low
# 2                 New Client  Young Adult            Low            Low
# 3                 New Client  Young Adult            Low            Low
# 4       Long Standing Client       Senior            Low            Low
# ...                      ...          ...            ...            ...
# 314163            New Client       Adults            Low            Low
# 314164  Long Standing Client       Adults         Medium           High
# 314165  Long Standing Client       Adults         Medium           High
# 314166            New Client  Young Adult            Low            Low
# 314167  Long Standing Client       Senior            Low            Low
#
#        Variation session_started  steps_status session_completed
# 0           Test               1             0                 1
# 1           Test               1             1                 1
# 2           Test               1             1                 1
# 3           Test               1             1                 1
# 4           Test               1             0                 1
# ...          ...             ...           ...               ...
# 314163   Control               1             0                 1
# 314164      Test               1             0                 1
# 314165      Test               1             0                 1
# 314166      Test               1             0                 1
# 314167   Control               1             0                 1
#
# [314168 rows x 21 columns]

# %%
# Save to csv
f.save_to_csv(df_join_clean, "df_join_clean.csv")
f.save_to_csv(merged_grouped,"both_groups_error_rate.csv")
# Out:
# DataFrame successfully saved to ../data/clean/df_join_clean.csv
# DataFrame successfully saved to ../data/clean/both_groups_error_rate.csv

# %%
# create a dummy function to export dataframe directly
def import_df_join_clean():
    return (
        df_join_clean
        )
